# %%
from pyspark.sql import SparkSession

# Criar sessão
spark = SparkSession.builder.appName("16_1").getOrCreate()

# %%
df = spark.read.json("V_OCORRENCIA_AMPLA.json")
df = df.toPandas()

# %%
df.head(5)
# Out:
#   Aerodromo_de_Destino Aerodromo_de_Origem  CLS Categoria_da_Aeronave  \
# 0                 SBKP                SBSL  L2J                   TPR
# 1                 SBCX                SBKP  L2J                   TPR
# 2                 None                None  L1P                   S11
# 3                 SBCY                SDAM  L1T                   TPP
# 4                 SIYL                SIYL  H2T                   TPP
#
#   Classificacao_da_Ocorrência Danos_a_Aeronave Data_da_Ocorrencia  \
# 0                   Incidente           Nenhum         2022-08-11
# 1             Incidente Grave             Leve         2021-08-06
# 2             Incidente Grave             Leve         2022-05-21
# 3                   Incidente             Leve         2022-02-12
# 4                   Incidente             Leve         2022-06-26
#
#                                    Descricao_do_Tipo Fase_da_Operacao  \
# 0  FALHA OU MAU FUNCIONAMENTO DE SISTEMA / COMPON...         Cruzeiro
# 1                        CONTATO ANORMAL COM A PISTA            Pouso
# 2                          OPERAÇÃO A BAIXA ALTITUDE          Manobra
# 3                                    COLISÃO COM AVE        Decolagem
# 4                                    COLISÃO NO SOLO   Estacionamento
#
#                                            Historico  ...           Operacao  \
# 0  A aeronave decolou do aeródromo Marechal Cunha...  ...        Voo Regular
# 1  A AERONAVE DECOLOU DO AERÓDROMO VIRACOPOS (SBK...  ...        Voo Regular
# 2  A aeronave decolou do aeródromo Asas do MS (SS...  ...  Operação Agrícola
# 3  A aeronave decolou do Aeródromo Estadual de Ca...  ...        Voo Privado
# 4  A aeronave decolou do heliponto Santuário Naci...  ...        Voo Privado
#
#                                     Operador  \
# 0        AZUL LINHAS AÉREAS BRASILEIRAS S.A.
# 1         AZUL LINHAS AEREAS BRASILEIRAS S.A
# 2         FIGUEIREDO AVIAÇÃO AGRÍCOLA EIRELI
# 3                   FENIX PARTICIPACOES LTDA
# 4  ANAPE EMPREENDIMENTOS IMOBILIÁRIOS-EIRELI
#
#                         Operador_Padronizado    PMD        PSSO        Regiao  \
# 0        AZUL LINHAS AÉREAS BRASILEIRAS S.A.  50790  verdadeiro         Norte
# 1                                       AZUL  61500  verdadeiro           Sul
# 2         FIGUEIREDO AVIAÇÃO AGRÍCOLA EIRELI   1800  verdadeiro  Centro-Oeste
# 3                   FENIX PARTICIPACOES LTDA   4740  verdadeiro       Sudeste
# 4  ANAPE EMPREENDIMENTOS IMOBILIÁRIOS-EIRELI   3000  verdadeiro       Sudeste
#
#   Tipo_ICAO Tipo_de_Aerodromo Tipo_de_Ocorrencia  UF
# 0      E195           Público             SCF-NP  TO
# 1      E295           Público                ARC  RS
# 2      IPAN                 -               LALT  MS
# 3      PC12           Público               BIRD  SP
# 4      A109           Público               GCOL  SP
#
# [5 rows x 45 columns]
